# %% [markdown]
# <a href="https://colab.research.google.com/github/poclab-web/AO-feature-selection/blob/main/%E3%82%B1%E3%83%A2%E3%82%A4%E3%83%B3%E3%83%95%E3%82%A9%E3%83%9E%E3%83%86%E3%82%A3%E3%83%83%E3%82%AF%E3%82%B9%E5%85%A5%E9%96%80%E6%9B%B8%E7%AC%AC5%E5%9B%9E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# condaのインストール

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# openbabelのインストール

# %%
# !conda install -c openbabel openbabel eigen -y &>/dev/null

# %%
# !conda list openbabel
# Out:
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel
# openbabel                 3.1.1           py310hbff9852_9    conda-forge

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# openbabelの呼び出し

# %%
from openbabel import openbabel, pybel

# %%
dir(openbabel)
# Out:
# ['AA_ALA',
#  'AA_ARG',
#  'AA_ASN',
#  'AA_ASP',
#  'AA_CYS',
#  'AA_GLN',
#  'AA_GLU',
#  'AA_GLY',
#  'AA_HIS',
#  'AA_ILE',
#  'AA_LEU',
#  'AA_LYS',
#  'AA_MET',
#  'AA_PHE',
#  'AA_PRO',
#  'AA_SER',
#  'AA_THR',
#  'AA_TRP',
#  'AA_TYR',
#  'AA_VAL',
#  'ACE',
#  'ACIDIC',
#  'ACYCLIC',
#  'AGENT',
#  'ALA',
#  'ALIPHATIC',
#  'ALPHA_CARBON',
#  'AMINO',
#  'AMINO_BACKBONE',
#  'AMINO_NUCLEO',
#  'ARG',
#  'AROMATIC',
#  'ASN',
#  'ASP',
#  'ASX',
#  'Ac',
#  'Actinium',
#  'Ag',
#  'Al',
#  'AliasData',
#  'AliasDataType',
#  'AllHydrogen',
#  'Aluminium',
#  'Am',
#  'Americium',
#  'AngleData',
#  'Antimony',
#  'Ar',
#  'Argon',
#  'Arsenic',
#  'As',
#  'Astatine',
#  'At',
#  'Au',
#  'B',
#  'BACKBONE',
#  'BASIC',
#  'BUFF_SIZE',
#  'BURIED',
#  'Ba',
#  'Barium',
#  'Be',
#  'Berkelium',
#  'Beryllium',
#  'Bh',
#  'Bi',
#  'Bismuth',
#  'Bk',
#  'Bohrium',
#  'Boron',
#  'Br',
#  'Bromine',
#  'C',
#  'CHARGED',
#  'COA',
#  'COENZYME',
#  'CYCLIC',
#  'CYS',
# ...

# %%
print(len(pybel.informats), len(pybel.outformats))
# Out:
# 148 134

# %%
pybel.informats
# Out:
# {'abinit': 'ABINIT Output Format',
#  'acesout': 'ACES output format',
#  'acr': 'ACR format',
#  'adfband': 'ADF Band output format',
#  'adfdftb': 'ADF DFTB output format',
#  'adfout': 'ADF output format',
#  'alc': 'Alchemy format',
#  'aoforce': 'Turbomole AOFORCE output format',
#  'arc': 'Accelrys/MSI Biosym/Insight II CAR format',
#  'axsf': 'XCrySDen Structure Format',
#  'bgf': 'MSI BGF format',
#  'box': 'Dock 3.5 Box format',
#  'bs': 'Ball and Stick format',
#  'c09out': 'Crystal 09 output format',
#  'c3d1': 'Chem3D Cartesian 1 format',
#  'c3d2': 'Chem3D Cartesian 2 format',
#  'caccrt': 'Cacao Cartesian format',
#  'can': 'Canonical SMILES format',
#  'car': 'Accelrys/MSI Biosym/Insight II CAR format',
#  'castep': 'CASTEP format',
#  'ccc': 'CCC format',
#  'cdjson': 'ChemDoodle JSON',
#  'cdx': 'ChemDraw binary format',
#  'cdxml': 'ChemDraw CDXML format',
#  'cif': 'Crystallographic Information File',
#  'ck': 'ChemKin format',
# ...

# %%
pybel.outformats
# Out:
# {'acesin': 'ACES input format',
#  'adf': 'ADF cartesian input format',
#  'alc': 'Alchemy format',
#  'ascii': 'ASCII format',
#  'bgf': 'MSI BGF format',
#  'box': 'Dock 3.5 Box format',
#  'bs': 'Ball and Stick format',
#  'c3d1': 'Chem3D Cartesian 1 format',
#  'c3d2': 'Chem3D Cartesian 2 format',
#  'cac': 'CAChe MolStruct format',
#  'caccrt': 'Cacao Cartesian format',
#  'cache': 'CAChe MolStruct format',
#  'cacint': 'Cacao Internal format',
#  'can': 'Canonical SMILES format',
#  'cdjson': 'ChemDoodle JSON',
#  'cdxml': 'ChemDraw CDXML format',
#  'cht': 'Chemtool format',
#  'cif': 'Crystallographic Information File',
#  'ck': 'ChemKin format',
#  'cml': 'Chemical Markup Language',
#  'cmlr': 'CML Reaction format',
#  'cof': 'Culgi object file format',
#  'com': 'Gaussian Input',
#  'confabreport': 'Confab report format',
#  'CONFIG': 'DL-POLY CONFIG',
#  'CONTCAR': 'VASP format',
#  'CONTFF': 'MDFF format',
#  'copy': 'Copy raw text',
# ...

# %% [markdown]
# smilesでの単一の分子の読み込むときの具体例

# %%
m = pybel.readstring("smiles", "C1=CC=C(C=C1)O")
m

# %% [markdown]
# xyz座標での分子の出力

# %%
print(m.write("xyz"))
# Out:
# 7
#
# C          0.00000        0.00000        0.00000
# C          0.00000        0.00000        0.00000
# C          0.00000        0.00000        0.00000
# C          0.00000        0.00000        0.00000
# C          0.00000        0.00000        0.00000
# C          0.00000        0.00000        0.00000
# O          0.00000        0.00000        0.00000

# %% [markdown]
# 構造最適化を行って、xyz座標での分子の出力

# %%
m.make3D(forcefield='mmff94', steps=1000)
print(m.write("xyz"))
# Out:
# 13
#
# C         -1.87568        0.03410       -0.00510
# C         -1.19721       -1.18589       -0.00406
# C          0.19853       -1.21088        0.00192
# C          0.90327       -0.01035        0.00680
# C          0.23498        1.20891        0.00620
# C         -1.15951        1.23167        0.00014
# O          2.26679        0.01257        0.01210
# H         -2.96253        0.05194       -0.00995
# H         -1.75770       -2.11714       -0.00797
# H          0.71278       -2.16634        0.00274
# H          0.79829        2.13748        0.01025
# H         -1.68618        2.18214       -0.00059
# H          2.58978       -0.90307        0.00844

# %% [markdown]
# MOPACの形式で出力

# %%
mopac_format = m.write("mop")
print(mopac_format)
# Out:
# PUT KEYWORDS HERE
#
#
# C  -1.87568 1  0.03410 1 -0.00510 1
# C  -1.19721 1 -1.18589 1 -0.00406 1
# C   0.19853 1 -1.21088 1  0.00192 1
# C   0.90327 1 -0.01035 1  0.00680 1
# C   0.23498 1  1.20891 1  0.00620 1
# C  -1.15951 1  1.23167 1  0.00014 1
# O   2.26679 1  0.01257 1  0.01210 1
# H  -2.96253 1  0.05194 1 -0.00995 1
# H  -1.75770 1 -2.11714 1 -0.00797 1
# H   0.71278 1 -2.16634 1  0.00274 1
# H   0.79829 1  2.13748 1  0.01025 1
# H  -1.68618 1  2.18214 1 -0.00059 1
# H   2.58978 1 -0.90307 1  0.00844 1

# %% [markdown]
# 初めの3行を削除する。

# %%
mopac_format = '\n'.join(mopac_format.splitlines()[3:])
